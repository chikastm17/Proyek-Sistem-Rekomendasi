# %%
import pandas as pd

file_path_lokal = r'D:\Sem 7\Sistem Rekomendasi\proyek-sistem-informasi\data-books\train.csv'
ratings_df = pd.read_csv(file_path_lokal)

print("Data berhasil dimuat!")
ratings_df.head()
# Out:
# Data berhasil dimuat!
#    user_id     item_id
# 0        8  0002005018
# 1        8  074322678X
# 2        8  0887841740
# 3        8  1552041778
# 4        8  1567407781

# %%
ratings_df.columns
# Out:
# Index(['user_id', 'item_id'], dtype='object')

# %%
ratings_df['rating'] = 1.0

# %%
from sklearn.preprocessing import LabelEncoder

user_encoder = LabelEncoder()
item_encoder = LabelEncoder()

ratings_df['user_id_enc'] = user_encoder.fit_transform(ratings_df['user_id'])
ratings_df['item_id_enc'] = item_encoder.fit_transform(ratings_df['item_id'])

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    ratings_df,
    test_size=0.2,
    random_state=42
)

print("Train:", train_df.shape)
print("Test :", test_df.shape)
# Out:
# Train: (215811, 5)
# Test : (53953, 5)

# %%
from scipy.sparse import csr_matrix

train_matrix = csr_matrix(
    (train_df['rating'], (train_df['user_id_enc'], train_df['item_id_enc']))
)

test_matrix = csr_matrix(
    (test_df['rating'], (test_df['user_id_enc'], test_df['item_id_enc']))
)

print("Sparse matrix berhasil dibuat!")
print("Train matrix shape:", train_matrix.shape)
print("Test matrix shape :", test_matrix.shape)
# Out:
# Sparse matrix berhasil dibuat!
# Train matrix shape: (13876, 123069)
# Test matrix shape : (13876, 123058)

# %%
import pandas as pd
import numpy as np
import scipy.sparse as sparse
from implicit.nearest_neighbours import ItemItemRecommender
from implicit.evaluation import train_test_split, mean_average_precision_at_k

print("Semua library berhasil di-import.")
file_path_lokal = r'D:\Sem 7\Sistem Rekomendasi\proyek-sistem-informasi\data-books\train.csv'
file_path_lokal = file_path_lokal.strip().strip('"')

try:
    df = pd.read_csv(file_path_lokal)
    print(f"\nData '{file_path_lokal}' berhasil dimuat.")
    
    df['user_id_cat'] = df['user_id'].astype("category")
    df['item_id_cat'] = df['item_id'].astype("category")
    
    n_users = len(df['user_id_cat'].cat.categories)
    n_items = len(df['item_id_cat'].cat.categories)
    # Pastikan angka ini sesuai dengan error Anda:
    print(f"Users: {n_users}, Items: {n_items}") 

    # ===== INI ADALAH PERBAIKAN KRUSIAL =====
    # Pastikan (baris, kolom) adalah (user, item)
    interactions_matrix = sparse.csr_matrix(
        (np.ones(df.shape[0]),
         (df['user_id_cat'].cat.codes,  # <-- Baris = USER
          df['item_id_cat'].cat.codes) # <-- Kolom = ITEM
        ),
        shape=(n_users, n_items) # <-- Shape = (Users, Items)
    )
    # =======================================
    
    print(f"Shape Matriks: {interactions_matrix.shape}") # <-- HARUS (Users, Items)
    
    train_matrix, test_matrix = train_test_split(interactions_matrix, train_percentage=0.8, random_state=42)
    print(f"Shape Train Matrix: {train_matrix.shape}") # <-- HARUS (Users, Items)

    print("\nMulai melatih model baseline (IBCF)...")
    model_baseline = ItemItemRecommender(K=20)
    model_baseline.fit(train_matrix) # <-- Benar: (Users, Items)
    print("Model baseline (IBCF) selesai dilatih.")

    print("\nMulai menghitung skor MAP@10 untuk model baseline...")
    map10_baseline = mean_average_precision_at_k(model_baseline,
                                                 train_matrix, # <-- Benar: (Users, Items)
                                                 test_matrix,  # <-- Benar: (Users, Items)
                                                 K=10,
                                                 num_threads=0) 

    print("\n--- HASIL MODEL BASELINE (IBCF) ---")
    print(f"Skor MAP@10: {map10_baseline}")

except Exception as e:
    print(f"\nTerjadi error di Sel 1: {e}")
# Out:
# Semua library berhasil di-import.
#
# Data 'D:\Sem 7\Sistem Rekomendasi\proyek-sistem-informasi\data-books\train.csv' berhasil dimuat.
# Users: 13876, Items: 123069
# Shape Matriks: (13876, 123069)
# Shape Train Matrix: (13876, 123069)
#
# Mulai melatih model baseline (IBCF)...
#   0%|          | 0/123069 [00:00<?, ?it/s]
# Model baseline (IBCF) selesai dilatih.
#
# Mulai menghitung skor MAP@10 untuk model baseline...
#   0%|          | 0/11454 [00:00<?, ?it/s]
# --- HASIL MODEL BASELINE (IBCF) ---
# Skor MAP@10: 0.018602178412511838

# %%
from implicit.als import AlternatingLeastSquares
import time
from threadpoolctl import threadpool_limits 
from implicit.evaluation import mean_average_precision_at_k



print("Library untuk model ALS (AlternatingLeastSquares) berhasil di-import.")

# --- 1. Inisialisasi Model Canggih (ALS) ---

# Rekomendasi perbaikan untuk kode Anda (library implicit)
model_als = AlternatingLeastSquares(factors=256, 
                                  regularization=0.1, 
                                  iterations=25, 
                                  alpha=15.0, 
                                  random_state=42)
print("Model ALS berhasil diinisialisasi.")

# --- 2. Latih Model ALS ---

print("\nMulai melatih model canggih (ALS)...")
start_time = time.time()

# Mengatasi peringatan MKL (opsional tapi disarankan)
# Ini akan mematikan 'internal threadpool' MKL agar tidak bentrok
threadpool_limits(1, "blas")

# latih model HANYA pada data latih (train_matrix)

model_als.fit(train_matrix.T.tocsr()) 
end_time = time.time()
print(f"Model ALS selesai dilatih. Waktu: {end_time - start_time:.2f} detik")

# --- 3. Evaluasi Model ALS (MAP@10) ---
print("\nMulai menghitung skor MAP@10 untuk model ALS...")

# Hitung skor MAP@10
map10_als = mean_average_precision_at_k(model_als,

                                        train_matrix.T.tocsr(),

                                        test_matrix.T.tocsr(),

                                        K=10,

                                        num_threads=0) # Menggunakan semua core
print("\n--- HASIL MODEL CANGGIH (ALS) ---")
print(f"Skor MAP@10: {map10_als}")
print("\n--- PERBANDINGAN ---")

# Ambil 'map10_baseline' dari variabel yang sudah Anda jalankan di sel sebelumnya

print(f"Baseline (IBCF) MAP@10: {map10_baseline}") 
print(f"Advanced (ALS) MAP@10 : {map10_als}")

if map10_als > map10_baseline:

    print("\nSELAMAT! Model ALS Anda berhasil mengalahkan baseline. 👍")
else:

    print("\nModel ALS belum mengalahkan baseline. Coba 'tuning' parameter (factors, regularization, iterations).")
# Out:
# Library untuk model ALS (AlternatingLeastSquares) berhasil di-import.
# Model ALS berhasil diinisialisasi.
#
# Mulai melatih model canggih (ALS)...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Model ALS selesai dilatih. Waktu: 38.29 detik
#
# Mulai menghitung skor MAP@10 untuk model ALS...
#   0%|          | 0/36233 [00:00<?, ?it/s]
# --- HASIL MODEL CANGGIH (ALS) ---
# Skor MAP@10: 0.023412103077860163
#
# --- PERBANDINGAN ---
# Baseline (IBCF) MAP@10: 0.018602178412511838
# Advanced (ALS) MAP@10 : 0.023412103077860163
#
# SELAMAT! Model ALS Anda berhasil mengalahkan baseline. 👍

# %%
import itertools
import pandas as pd

# 1. Tentukan 'Kotak Pencarian' (Search Grid) Anda
#    Mulailah dengan sedikit kombinasi agar tidak terlalu lama!
param_grid = {
    'factors': [100, 256],
    'regularization': [0.1, 0.5],
    'alpha': [15.0, 40.0],
    'iterations': [25] # Kita kunci dulu iterasinya agar lebih cepat
}

# 2. Siapkan tempat untuk menyimpan hasil
results = []
best_map10 = -1
best_params = {}

# Buat semua kombinasi parameter
# Gunakan itertools.product untuk membuat semua kombinasi
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

print(f"Total kombinasi yang akan dicoba: {len(all_params)}")

# 3. Mulai Looping
for params in all_params:
    print(f"\nMencoba parameter: {params}")
    
    # Inisialisasi model dengan parameter dari grid
    model_als_tuned = AlternatingLeastSquares(
        factors=params['factors'],
        regularization=params['regularization'],
        alpha=params['alpha'],
        iterations=params['iterations'],
        random_state=42,
        num_threads=0 
    )
    
    # Latih model
    start_time = time.time()
    with threadpool_limits(1, "blas"):
        model_als_tuned.fit(train_matrix.T.tocsr())
    train_time = time.time() - start_time
    
    # Evaluasi model
    map10_als = mean_average_precision_at_k(
        model_als_tuned,
        train_matrix.T.tocsr(),
        test_matrix.T.tocsr(),
        K=10,
        num_threads=0
    )
    
    print(f"Hasil MAP@10: {map10_als:.6f} (Waktu latih: {train_time:.2f} detik)")
    
    # Simpan hasil
    current_result = params.copy()
    current_result['map10'] = map10_als
    current_result['train_time'] = train_time
    results.append(current_result)
    
    # Cek apakah ini model terbaik sejauh ini
    if map10_als > best_map10:
        print(f"SKOR BARU TERBAIK DITEMUKAN! {map10_als:.6f}")
        best_map10 = map10_als
        best_params = params

# 4. Tampilkan hasil akhir
print("\n--- PROSES FINE-TUNING SELESAI ---")
print(f"Skor MAP@10 Terbaik : {best_map10:.6f}")
print(f"Parameter Terbaik    : {best_params}")

# Anda juga bisa melihat semua hasil dalam bentuk tabel
results_df = pd.DataFrame(results)
print("\n--- Ringkasan Semua Hasil ---")
print(results_df.sort_values(by='map10', ascending=False))
# Out:
# Total kombinasi yang akan dicoba: 8
#
# Mencoba parameter: {'factors': 100, 'regularization': 0.1, 'alpha': 15.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.023196 (Waktu latih: 3.76 detik)
# SKOR BARU TERBAIK DITEMUKAN! 0.023196
#
# Mencoba parameter: {'factors': 100, 'regularization': 0.1, 'alpha': 40.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.024694 (Waktu latih: 3.56 detik)
# SKOR BARU TERBAIK DITEMUKAN! 0.024694
#
# Mencoba parameter: {'factors': 100, 'regularization': 0.5, 'alpha': 15.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.023345 (Waktu latih: 3.79 detik)
#
# Mencoba parameter: {'factors': 100, 'regularization': 0.5, 'alpha': 40.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.025250 (Waktu latih: 3.54 detik)
# SKOR BARU TERBAIK DITEMUKAN! 0.025250
#
# Mencoba parameter: {'factors': 256, 'regularization': 0.1, 'alpha': 15.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.023412 (Waktu latih: 17.25 detik)
#
# Mencoba parameter: {'factors': 256, 'regularization': 0.1, 'alpha': 40.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.024671 (Waktu latih: 19.00 detik)
#
# Mencoba parameter: {'factors': 256, 'regularization': 0.5, 'alpha': 15.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.023428 (Waktu latih: 21.60 detik)
#
# Mencoba parameter: {'factors': 256, 'regularization': 0.5, 'alpha': 40.0, 'iterations': 25}
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/36233 [00:00<?, ?it/s]
# Hasil MAP@10: 0.024707 (Waktu latih: 22.64 detik)
#
# --- PROSES FINE-TUNING SELESAI ---
# Skor MAP@10 Terbaik : 0.025250
# Parameter Terbaik    : {'factors': 100, 'regularization': 0.5, 'alpha': 40.0, 'iterations': 25}
#
# --- Ringkasan Semua Hasil ---
#    factors  regularization  alpha  iterations     map10  train_time
# 3      100             0.5   40.0          25  0.025250    3.542059
# 7      256             0.5   40.0          25  0.024707   22.635560
# 1      100             0.1   40.0          25  0.024694    3.555607
# 5      256             0.1   40.0          25  0.024671   18.996905
# 6      256             0.5   15.0          25  0.023428   21.595454
# 4      256             0.1   15.0          25  0.023412   17.254363
# 2      100             0.5   15.0          25  0.023345    3.791715
# 0      100             0.1   15.0          25  0.023196    3.758940

# %%
from implicit.als import AlternatingLeastSquares
import time
from threadpoolctl import threadpool_limits 
from implicit.evaluation import mean_average_precision_at_k



print("Library untuk model ALS (AlternatingLeastSquares) berhasil di-import.")

# --- 1. Inisialisasi Model Canggih (ALS) ---

# Rekomendasi perbaikan untuk kode Anda (library implicit)
model_als = AlternatingLeastSquares(factors=100, 
                                  regularization=0.5, 
                                  iterations=25, 
                                  alpha=40.0, 
                                  random_state=42)
print("Model ALS berhasil diinisialisasi.")

# --- 2. Latih Model ALS ---

print("\nMulai melatih model canggih (ALS)...")
start_time = time.time()

# Mengatasi peringatan MKL (opsional tapi disarankan)
# Ini akan mematikan 'internal threadpool' MKL agar tidak bentrok
threadpool_limits(1, "blas")

# latih model HANYA pada data latih (train_matrix)

model_als.fit(train_matrix.T.tocsr()) 
end_time = time.time()
print(f"Model ALS selesai dilatih. Waktu: {end_time - start_time:.2f} detik")

# --- 3. Evaluasi Model ALS (MAP@10) ---
print("\nMulai menghitung skor MAP@10 untuk model ALS...")

# Hitung skor MAP@10
map10_als = mean_average_precision_at_k(model_als,

                                        train_matrix.T.tocsr(),

                                        test_matrix.T.tocsr(),

                                        K=10,

                                        num_threads=0) # Menggunakan semua core
print("\n--- HASIL MODEL CANGGIH (ALS) ---")
print(f"Skor MAP@10: {map10_als}")
print("\n--- PERBANDINGAN ---")

# Ambil 'map10_baseline' dari variabel yang sudah Anda jalankan di sel sebelumnya

print(f"Baseline (IBCF) MAP@10: {map10_baseline}") 
print(f"Advanced (ALS) MAP@10 : {map10_als}")

if map10_als > map10_baseline:

    print("\nSELAMAT! Model ALS Anda berhasil mengalahkan baseline. 👍")
else:

    print("\nModel ALS belum mengalahkan baseline. Coba 'tuning' parameter (factors, regularization, iterations).")
# Out:
# Library untuk model ALS (AlternatingLeastSquares) berhasil di-import.
# Model ALS berhasil diinisialisasi.
#
# Mulai melatih model canggih (ALS)...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Model ALS selesai dilatih. Waktu: 3.66 detik
#
# Mulai menghitung skor MAP@10 untuk model ALS...
#   0%|          | 0/36233 [00:00<?, ?it/s]
# --- HASIL MODEL CANGGIH (ALS) ---
# Skor MAP@10: 0.025249568433851555
#
# --- PERBANDINGAN ---
# Baseline (IBCF) MAP@10: 0.018602178412511838
# Advanced (ALS) MAP@10 : 0.025249568433851555
#
# SELAMAT! Model ALS Anda berhasil mengalahkan baseline. 👍
